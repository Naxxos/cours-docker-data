# %% [markdown]
# ## Téléchargement de 1 millions de transaction de la DVF sur l'année 2020

# %%
# !wget https://files.data.gouv.fr/geo-dvf/latest/csv/2023/full.csv.gz
# Out:
# --2024-03-12 23:39:22--  https://files.data.gouv.fr/geo-dvf/latest/csv/2023/full.csv.gz
# Resolving files.data.gouv.fr (files.data.gouv.fr)... 51.38.54.240
# Connecting to files.data.gouv.fr (files.data.gouv.fr)|51.38.54.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 41755884 (40M) [application/octet-stream]
# Saving to: ‘full.csv.gz’
#
# full.csv.gz         100%[===================>]  39.82M  9.47MB/s    in 4.4s
#
# 2024-03-12 23:39:27 (9.12 MB/s) - ‘full.csv.gz’ saved [41755884/41755884]

# %%
import pandas as pd

df = pd.read_csv('./full.csv.gz', compression='gzip', low_memory=False)

# %%
df.head(10)
# Out:
#   id_mutation date_mutation  numero_disposition nature_mutation  \
# 0      2023-1    2023-01-05                   1           Vente
# 1      2023-1    2023-01-05                   1           Vente
# 2      2023-1    2023-01-05                   1           Vente
# 3      2023-2    2023-01-03                   1           Vente
# 4      2023-3    2023-01-05                   1           Vente
# 5      2023-3    2023-01-05                   1           Vente
# 6      2023-3    2023-01-05                   1           Vente
# 7      2023-4    2023-01-03                   1           Vente
# 8      2023-5    2023-01-06                   1           Vente
# 9      2023-6    2023-01-06                   2         Echange
#
#    valeur_fonciere  adresse_numero adresse_suffixe        adresse_nom_voie  \
# 0        1070000.0           184.0             NaN          ALL DES HETRES
# 1        1070000.0           159.0             NaN          ALL DES HETRES
# ...

# %%
df.columns
# Out:
# Index(['id_mutation', 'date_mutation', 'numero_disposition', 'nature_mutation',
#        'valeur_fonciere', 'adresse_numero', 'adresse_suffixe',
#        'adresse_nom_voie', 'adresse_code_voie', 'code_postal', 'code_commune',
#        'nom_commune', 'code_departement', 'ancien_code_commune',
#        'ancien_nom_commune', 'id_parcelle', 'ancien_id_parcelle',
#        'numero_volume', 'lot1_numero', 'lot1_surface_carrez', 'lot2_numero',
#        'lot2_surface_carrez', 'lot3_numero', 'lot3_surface_carrez',
#        'lot4_numero', 'lot4_surface_carrez', 'lot5_numero',
#        'lot5_surface_carrez', 'nombre_lots', 'code_type_local', 'type_local',
#        'surface_reelle_bati', 'nombre_pieces_principales',
#        'code_nature_culture', 'nature_culture', 'code_nature_culture_speciale',
#        'nature_culture_speciale', 'surface_terrain', 'longitude', 'latitude'],
#       dtype='object')

# %% [markdown]
# Plus d'infos sur les colonnes : https://www.data.gouv.fr/fr/datasets/demandes-de-valeurs-foncieres/

# %%
df.groupby(by="code_departement").size()
# Out:
# code_departement
# 1      14264
# 2      15710
# 3      14373
# 4       4413
# 5       5985
#        ...
# 974     5959
# 29      3120
# 2A      3402
# 2B       932
# 30      8930
# Length: 99, dtype: int64

# %%
from sqlalchemy import create_engine

engine = create_engine('postgresql+psycopg2://shared:changeme1234@postgres/shared', echo=False)
df.head(100_000).to_sql(name='dvf', con=engine)
# Out:
# 375

# %%
# !pip install polars
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.0/26.0 MB 8.6 MB/s eta 0:00:0000:0100:01m
# ...

# %%
import polars as pl

# %%
df = pl.read_csv("full.csv.gz", has_header=True, infer_schema_length=1000000)

# %%
df.head(10)
# Out:
# shape: (10, 40)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ id_mutati ┆ date_muta ┆ numero_di ┆ nature_mu ┆ … ┆ nature_cu ┆ surface_t ┆ longitude ┆ latitude │
# │ on        ┆ tion      ┆ sposition ┆ tation    ┆   ┆ lture_spe ┆ errain    ┆ ---       ┆ ---      │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ciale     ┆ ---       ┆ f64       ┆ f64      │
# │ str       ┆ str       ┆ i64       ┆ str       ┆   ┆ ---       ┆ i64       ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆ str       ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2023-1    ┆ 2023-01-0 ┆ 1         ┆ Vente     ┆ … ┆ null      ┆ null      ┆ 6.019949  ┆ 46.24745 │
# │           ┆ 5         ┆           ┆           ┆   ┆           ┆           ┆           ┆ 8        │
# ...

# %%
df.group_by("id_mutation").first().group_by("code_departement").agg(pl.col("valeur_fonciere").sum())
# Out:
# shape: (97, 2)
# ┌──────────────────┬─────────────────┐
# │ code_departement ┆ valeur_fonciere │
# │ ---              ┆ ---             │
# │ str              ┆ f64             │
# ╞══════════════════╪═════════════════╡
# │ 88               ┆ 4.1006e8        │
# │ 51               ┆ 2.9600e8        │
# │ 15               ┆ 1.3944e8        │
# │ 86               ┆ 4.6721e8        │
# │ 90               ┆ 1.5010e8        │
# │ …                ┆ …               │
# │ 92               ┆ 7.6611e9        │
# │ 87               ┆ 4.5629e8        │
# │ 07               ┆ 4.4204e8        │
# │ 971              ┆ 1.2763e8        │
# │ 77               ┆ 3.2723e9        │
# └──────────────────┴─────────────────┘

# %%
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1136, in Connection._commit_impl(self)
#    1135 try:
# -> 1136     self.engine.dialect.do_commit(self.connection)
#    1137 except BaseException as e:
#
# File /opt/conda/lib/python3.11/site-packages/sqlalchemy/engine/default.py:695, in DefaultDialect.do_commit(self, dbapi_connection)
#     694 def do_commit(self, dbapi_connection):
# --> 695     dbapi_connection.commit()
#
# OperationalError: server closed the connection unexpectedly
# 	This probably means the server terminated abnormally
# 	before or while processing the request.
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[45], line 4
#       1 from sqlalchemy import create_engine
# ...

# %%
from minio import Minio
import os

minio_client = Minio(
        endpoint="minio:9000",
        access_key=os.environ["MINIO_ROOT_USER"],
        secret_key=os.environ["MINIO_ROOT_PASSWORD"],
        secure=False
    )

minio_client.make_bucket("dvf")
# Out:
# ---------------------------------------------------------------------------
# S3Error                                   Traceback (most recent call last)
# Cell In[7], line 11
#       2 import os
#       4 minio_client = Minio(
#       5         endpoint="minio:9000",
#       6         access_key=os.environ["MINIO_ROOT_USER"],
#       7         secret_key=os.environ["MINIO_ROOT_PASSWORD"],
#       8         secure=False
#       9     )
# ---> 11 minio_client.make_bucket("dvf")
#
# File /opt/conda/lib/python3.11/site-packages/minio/api.py:656, in Minio.make_bucket(self, bucket_name, location, object_lock)
#     654     SubElement(element, "LocationConstraint", location)
#     655     body = getbytes(element)
# --> 656 self._url_open(
#     657     "PUT",
#     658     location,
#     659     bucket_name=bucket_name,
#     660     body=body,
#     661     headers=headers,
#     662 )
#     663 self._region_map[bucket_name] = location
#
# ...
